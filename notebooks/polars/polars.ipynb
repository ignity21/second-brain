# %%
import polars as pl
from rich import print

# %%
sales = pl.read_csv("practice_sales.csv")
print(sales.shape)
print(sales.schema) # column names and dtype
print(sales.glimpse()) # useful if we have many columns
sales.head(3)
# Out:
# (1003, 20)
# Schema({'order_id': String, 'order_datetime': String, 'customer_id': String, 'region': String, 'channel': String,
# 'category': String, 'product': String, 'quantity': Int64, 'unit_price': Float64, 'discount_pct': Int64, 'revenue':
# Float64, 'cost': Float64, 'status': String, 'payment_method': String, 'is_member': Boolean, 'customer_age': Int64,
# 'rating': Int64, 'coupon_code': String, 'sales_rep': String, 'notes': String})
# Rows: 1003
# Columns: 20
# $ order_id        <str> 'ORD-00001', 'ORD-00002', 'ORD-00003', 'ORD-00004', 'ORD-00005', 'ORD-00006', 'ORD-00007', 'ORD-00008', 'ORD-00009', 'ORD-00010'
# $ order_datetime  <str> '2026-05-12 12:18:00', '2025-02-19 20:40:00', '2025-03-24 13:39:00', '2026-03-02 08:21:00', '2026-02-02 12:01:00', '2025-01-02 15:51:00', '2025-04-22 22:47:00', '2025-08-02 14:47:00', '2026-06-10 14:51:00', '2025-03-27 19:54:00'
# $ customer_id     <str> 'CUST-0056', 'CUST-0062', 'CUST-0037', 'CUST-0018', 'CUST-0112', 'CUST-0167', 'CUST-0200', 'CUST-0020', 'CUST-0109', 'CUST-0184'
# $ region          <str> 'Central', 'Central', 'East', 'Central', 'Central', 'East', 'East', 'North', 'West', 'West'
# $ channel         <str> 'partner', 'partner', 'mobile', 'mobile', 'web', 'web', 'store', 'web', 'store', 'store'
# $ category        <str> 'Home', 'Books', 'Sports', 'Books', 'Books', 'Electronics', 'Sports', 'Sports', 'Sports', 'Home'
# $ product         <str> 'Storage Box', 'Python Basics', 'Dumbbell', 'Finance 101', 'Finance 101', 'Headphones', 'Dumbbell', 'Running Shoes', 'Basketball', 'Lamp'
# $ quantity        <i64> 1, 4, 5, 5, 3, 5, 3, 6, 3, 5
# $ unit_price      <f64> 174.61, 211.97, 524.49, 801.73, 268.09, 121.34, 552.25, 215.36, 29.56, 448.7
# $ discount_pct    <i64> 10, 0, 5, 5, 0, 25, 10, 5, 15, 20
# $ revenue         <f64> 157.15, 0.0, 2491.33, 3808.22, 804.27, 455.03, 1491.08, 0.0, 75.38, 1794.8
# $ cost            <f64> 116.87, 0.0, 1688.46, 2395.21, 540.19, 287.92, 944.71, 0.0, 60.17, 1362.51
# $ status          <str> 'completed', 'cancelled', 'pending', 'completed', 'completed', 'pending', 'pending', 'cancelled', 'completed', 'pending'
# $ payment_method  <str> 'credit_card', 'credit_card', 'apple_pay', 'bank_transfer', 'paypal', 'paypal', 'paypal', 'apple_pay', 'paypal', 'apple_pay'
# $ is_member      <bool> True, False, False, True, False, False, True, True, True, True
# $ customer_age    <i64> 37, 40, 27, 70, 56, 48, 47, 74, 46, 23
# $ rating          <i64> 4, 3, 2, 3, 4, null, 1, 4, 4, null
# $ coupon_code     <str> 'VIP', null, 'VIP', null, 'WELCOME10', 'VIP', 'SUMMER25', 'VIP', 'SUMMER25', null
# $ sales_rep       <str> 'Alice', 'Bob', null, 'Alice', 'Bob', 'Diana', null, 'Evan', 'Evan', 'Evan'
# $ notes           <str> 'delayed shipment', 'priority customer', 'delayed shipment', 'gift order', null, 'address corrected', 'delayed shipment', null, 'delayed shipment', null
# None
# shape: (3, 20)
# ┌───────────┬────────────┬────────────┬─────────┬───┬────────┬────────────┬───────────┬────────────┐
# │ order_id  ┆ order_date ┆ customer_i ┆ region  ┆ … ┆ rating ┆ coupon_cod ┆ sales_rep ┆ notes      │
# │ ---       ┆ time       ┆ d          ┆ ---     ┆   ┆ ---    ┆ e          ┆ ---       ┆ ---        │
# │ str       ┆ ---        ┆ ---        ┆ str     ┆   ┆ i64    ┆ ---        ┆ str       ┆ str        │
# │           ┆ str        ┆ str        ┆         ┆   ┆        ┆ str        ┆           ┆            │
# ╞═══════════╪════════════╪════════════╪═════════╪═══╪════════╪════════════╪═══════════╪════════════╡
# │ ORD-00001 ┆ 2026-05-12 ┆ CUST-0056  ┆ Central ┆ … ┆ 4      ┆ VIP        ┆ Alice     ┆ delayed    │
# │           ┆ 12:18:00   ┆            ┆         ┆   ┆        ┆            ┆           ┆ shipment   │
# │ ORD-00002 ┆ 2025-02-19 ┆ CUST-0062  ┆ Central ┆ … ┆ 3      ┆ null       ┆ Bob       ┆ priority   │
# │           ┆ 20:40:00   ┆            ┆         ┆   ┆        ┆            ┆           ┆ customer   │
# │ ORD-00003 ┆ 2025-03-24 ┆ CUST-0037  ┆ East    ┆ … ┆ 2      ┆ VIP        ┆ null      ┆ delayed    │
# │           ┆ 13:39:00   ┆            ┆         ┆   ┆        ┆            ┆           ┆ shipment   │
# └───────────┴────────────┴────────────┴─────────┴───┴────────┴────────────┴───────────┴────────────┘

# %% [markdown]
# # Selection
# - By Rows: `df[0]`, `df[-1]`, `df[1:3]`
# - By Columns: `df["region"]`, `df[["region", "channel"]]`
# - By Both (row first, then columns): `df[:3, ["region", "channel"]]`
# - `.select()`: `df.select("region", "channel")`
#
# # Sorting
# - `df.sort("quantity", descending=True)` # default ascending
# - By multiple columns: `df.sort("quantity", "product")`
#
# # Summarizing
# - Finding extreme values: `df.top_k(3, by="quantity")` or `bottom_k`
# - `df.describe()`
