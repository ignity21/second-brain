# %%
import akshare as ak

# %%
df = ak.fund_etf_hist_sina(symbol="sh510050")
df.tail()
# Out:
#             date   open   high    low  close     volume
# 4281  2022-09-27  2.657  2.685  2.648  2.681  741885615
# 4282  2022-09-28  2.669  2.676  2.648  2.651  737843151
# 4283  2022-09-29  2.668  2.683  2.636  2.651  732951806
# 4284  2022-09-30  2.654  2.674  2.647  2.650  751490841
# 4285  2022-10-10  2.650  2.653  2.580  2.586  778160642

# %%
df.close.plot()
# Out:
# <AxesSubplot: >
